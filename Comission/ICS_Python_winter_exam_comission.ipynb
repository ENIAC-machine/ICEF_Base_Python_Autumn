# %% [markdown]
# # Instructions
#
# <p style="line-height: 2.0;">
#
#
#
# Exam instructions:\
#     \
#     You are given a file "Surname_Name_{i}.ipynb". You should replace ```Surname``` with your Surname, ```Name``` with your name and ```{i}``` with the
#     variant that you will be given. There will be 3 main tasks in the file and one bonus task. **It is only mandatory to solve the first 3 tasks**.\
#     \
#     You are allowed to use only 5 libraries for the exam: ```typing``` (for type hints), ```math``` (for mathematical expressions), ```numpy```,
#     ```pandas``` and ```matplotlib```. **Any other libraries are strictly prohibited**.\
#     \
#     All the import statements must be located in the designated section ```Imports``` in the file.\
#     \
#     You may earn bonus points for each task **including the bonus one** by providing type hints. Each type hint put correctly (including the function's output) earns 2 bonus points. Note that you can't receive more than **100** points for the exam, even if the total amount of points you get exceeds that number. \
#     \
#     In some tasks for the ease of debugging you will be given a couple of test cases, but please note that **you will not be given all the test cases
#     your task will go through when it will be graded**, only a subset of those.\
#     \
#     For a full grade for the task your solution must (of course) yield the correct output, be stable (the function must give correct outputs consistently) and use only the libraries that are allowed by the task (if nothing is stated about the allowed libraries you can only use the four libraries provided above).\
#     \
#     If you are going to be crying, please do it quietly so you don't disturb other students' work / crying.\
#     \
#     Best of luck!
#
# </p>

# %% [markdown]
# # Imports

# %%
from IPython.core.display import HTML #fancy table formatting, don't worry about it
table_css = 'table {align:left;display:block} '
HTML('<style>{}</style>'.format(table_css))

### your imports here

# %% [markdown]
# # Problem 1 (20 pts). Quantum State Fidelity

# %% [markdown]
# You are given a file `states.txt` with quantum state amplitudes in the format:
#
#     1: alpha=0.707+0.707j ; beta=0.0+0.0j
#     2: alpha=рџ—їрџ—їрџ—ї ; beta=0.5+0.5j
#     3: alpha=0.6+0.8j ; beta=0.0+0.0j
#
# Your task is to read the file, discarding lines where variables can't be converted to complex numbers. Calculate the state fidelity with the reference state |ψ₀⟩ = |0⟩ (alpha=1, beta=0) using:
#
# $$\Large F = |\alpha_0^** \cdot \alpha + \beta_0^* \cdot \beta|$$
#
# Here $\alpha_0^* = 1$, $\beta_0^* = 0$. Write out to `fidelity.txt`:
#
#     1: F=0.9999999999999998
#     3: F=0.9999999999999998
#
# Implement function `quantum_fidelity(filename)` that returns the number of valid lines processed
#
# For this task you can't use any libraries except for the `typing` library

# %%
###your solution here

# %% [markdown]
# # Problem 2 (50 pts).Wave Interference Simulator

# %% [markdown]
# Create a function `wave_sim` with 7 arguments:
#
# 1) `N` (int, default=None): Grid size
# 2) `M` (int): Number of time steps
# 3) `sources` (numpy array, default=None): Source positions [x, y]
# 4) `freq` (float): Oscillation frequency (0 < freq < 1)
# 5) `damping` (bool): Apply damping at boundaries
# 6) `seed` (int, default=None): Random seed
# 7) `grid` (numpy array, default=None): Initial grid state
#
# Simulation rules:
#
# * Initialize NxN grid of zeros
#
# * At each time step:
#     1) Each source emits: `amplitude = sin(2π * freq * t)`
#     2) Wave propagates: each cell becomes average of 4 neighbors + source contribution
#     3) If `damping`=True: multiply boundary cells by 0.9 every 5 iterations (starting at t=0)
#
# User must pass either `N` or `grid` (validate length matches if both provided)
# If `sources` is None, generate 2-4 random source positions
#
# See example:
#
#     >>> waves = wave_sim(N=5, M=3, sources=np.array([[2,2]]), freq=0.5, damping=False, seed=42)
#     >>> print(len(waves))
#     3
#
# Return list of numpy arrays (one per time step)

# %%
###your code here

# %% [markdown]
# # Problem 3 (30 pts). The Latest Login in 2020

# %% [markdown]
# Table: `Logins`
#
#
# | Column Name    | Type     |
# |----------------|----------|
# | user_id        | int      |
# | time_stamp     | datetime |
#
# (user_id, time_stamp) is the primary key (combination of columns with unique values) for this table.\
# Each row contains information about the login time for the user with ID user_id.
#
#
# Write a solution to report the latest login for all users in the year 2020. Do not include the users who did not login in 2020.
#
# Return the result table in any order.
#
# The result format is in the following example.
#
#
#
# Example 1:
#
# Input:
# Logins table:
#
# | user_id | time_stamp          |
# |---------|---------------------|
# | 6       | 2020-06-30 15:06:07 |
# | 6       | 2021-04-21 14:06:06 |
# | 6       | 2019-03-07 00:18:15 |
# | 8       | 2020-02-01 05:10:53 |
# | 8       | 2020-12-30 00:46:50 |
# | 2       | 2020-01-16 02:49:50 |
# | 2       | 2019-08-25 07:59:08 |
# | 14      | 2019-07-14 09:00:00 |
# | 14      | 2021-01-06 11:59:59 |
#
# Output:
#
# | user_id | last_stamp          |
# |---------|---------------------|
# | 6       | 2020-06-30 15:06:07 |
# | 8       | 2020-12-30 00:46:50 |
# | 2       | 2020-01-16 02:49:50 |
#
# Explanation:
# User 6 logged into their account 3 times but only once in 2020, so we include this login in the result table.\
# User 8 logged into their account 2 times in 2020, once in February and once in December. We include only the latest one (December) in the result table.\
# User 2 logged into their account 2 times but only once in 2020, so we include this login in the result table.\
# User 14 did not login in 2020, so we do not include them in the result table.
#
#
# *Hint: use element.year to extract the year of the timestamp*

# %%
###your code here

# %% [markdown]
# Below is the script for checking yourself

# %%
from datetime import datetime

# Test cases
test_inputs = []
test_outputs = []

# Test 1: Example from problem
test_inputs.append(pd.DataFrame({
    'user_id': [6, 6, 6, 8, 8, 2, 2, 14, 14],
    'time_stamp': pd.to_datetime([
        '2020-06-30 15:06:07',
        '2021-04-21 14:06:06',
        '2019-03-07 00:18:15',
        '2020-02-01 05:10:53',
        '2020-12-30 00:46:50',
        '2020-01-16 02:49:50',
        '2019-08-25 07:59:08',
        '2019-07-14 09:00:00',
        '2021-01-06 11:59:59'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [2, 6, 8],
    'last_stamp': pd.to_datetime([
        '2020-01-16 02:49:50',
        '2020-06-30 15:06:07',
        '2020-12-30 00:46:50'
    ])
}))

# Test 2: No 2020 logins
test_inputs.append(pd.DataFrame({
    'user_id': [1, 1, 2, 3],
    'time_stamp': pd.to_datetime([
        '2019-01-01 10:00:00',
        '2021-01-01 10:00:00',
        '2019-12-31 23:59:59',
        '2021-01-01 00:00:01'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [],
    'last_stamp': []
}))

# Test 3: All users login only once in 2020
test_inputs.append(pd.DataFrame({
    'user_id': [1, 2, 3, 4],
    'time_stamp': pd.to_datetime([
        '2020-01-01 00:00:00',
        '2020-06-15 12:30:00',
        '2020-12-31 23:59:59',
        '2020-07-04 16:20:30'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [1, 2, 3, 4],
    'last_stamp': pd.to_datetime([
        '2020-01-01 00:00:00',
        '2020-06-15 12:30:00',
        '2020-12-31 23:59:59',
        '2020-07-04 16:20:30'
    ])
}))

# Test 4: Multiple logins in 2020 for same user
test_inputs.append(pd.DataFrame({
    'user_id': [5, 5, 5, 5, 5],
    'time_stamp': pd.to_datetime([
        '2020-01-15 08:00:00',
        '2020-03-20 10:30:00',
        '2020-06-10 14:15:00',
        '2020-09-05 18:45:00',
        '2020-11-25 22:00:00'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [5],
    'last_stamp': pd.to_datetime(['2020-11-25 22:00:00'])
}))

# Test 5: Mixed years, multiple users
test_inputs.append(pd.DataFrame({
    'user_id': [10, 10, 10, 20, 20, 30, 30, 30],
    'time_stamp': pd.to_datetime([
        '2019-12-31 23:59:59',
        '2020-01-01 00:00:00',
        '2020-12-31 23:59:59',
        '2020-06-01 12:00:00',
        '2019-06-01 12:00:00',
        '2021-01-01 00:00:00',
        '2020-03-15 10:10:10',
        '2019-03-15 10:10:10'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [10, 20, 30],
    'last_stamp': pd.to_datetime([
        '2020-12-31 23:59:59',
        '2020-06-01 12:00:00',
        '2020-03-15 10:10:10'
    ])
}))

# Test 6: Edge case - exact year boundaries
test_inputs.append(pd.DataFrame({
    'user_id': [1, 1, 2, 2],
    'time_stamp': pd.to_datetime([
        '2019-12-31 23:59:59',
        '2020-01-01 00:00:00',
        '2020-12-31 23:59:59',
        '2021-01-01 00:00:00'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [1, 2],
    'last_stamp': pd.to_datetime([
        '2020-01-01 00:00:00',
        '2020-12-31 23:59:59'
    ])
}))

# Test 7: Single user, single 2020 login
test_inputs.append(pd.DataFrame({
    'user_id': [100],
    'time_stamp': pd.to_datetime(['2020-07-15 12:34:56'])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [100],
    'last_stamp': pd.to_datetime(['2020-07-15 12:34:56'])
}))

# Test 8: Large user IDs, various patterns
test_inputs.append(pd.DataFrame({
    'user_id': [999, 999, 1000, 1001, 1001, 1001],
    'time_stamp': pd.to_datetime([
        '2020-02-14 09:00:00',
        '2020-02-14 09:00:01',
        '2019-01-01 00:00:00',
        '2020-05-10 10:10:10',
        '2020-08-20 20:20:20',
        '2020-11-30 15:45:30'
    ])
}))
test_outputs.append(pd.DataFrame({
    'user_id': [999, 1001],
    'last_stamp': pd.to_datetime([
        '2020-02-14 09:00:01',
        '2020-11-30 15:45:30'
    ])
}))


# Testing script
def compare_dataframes(df1, df2):
    """Compare two dataframes for equality."""
    if df1.shape != df2.shape:
        return False
    
    if len(df1) == 0 and len(df2) == 0:
        return True
    
    # Sort both dataframes by user_id
    df1_sorted = df1.sort_values('user_id').reset_index(drop=True)
    df2_sorted = df2.sort_values('user_id').reset_index(drop=True)
    
    # Check user_ids
    if not df1_sorted['user_id'].equals(df2_sorted['user_id']):
        return False
    
    # Check timestamps
    for i in range(len(df1_sorted)):
        if df1_sorted.iloc[i]['last_stamp'] != df2_sorted.iloc[i]['last_stamp']:
            return False
    
    return True


# Run tests
failed_count = 0
total_tests = len(test_inputs)

for i in range(total_tests):
    try:
        result = latest_login(test_inputs[i])
        if not compare_dataframes(result, test_outputs[i]):
            failed_count += 1
    except Exception as e:
        failed_count += 1

print(f"Failed: {failed_count}/{total_tests}")

# %% [markdown]
# Problem 4 (Bonus, 60 pts). Polar Complex Numbers

# %% [markdown]
# Implement class `ComplexPolar` for complex numbers in polar form (r, θ) instead of (a, bi).
#
# Methods to implement:
#
# `__init__(self, real=None, imag=None)` - accepts Cartesian coordinates, stores as (r, θ)
#
# `__repr__` - returns string like "2.00∠45.00°"
#
# `__eq__` - compares two ComplexPolar instances (tolerance 1e-6)
#
# `__mul__` - multiplies two ComplexPolar (r₁r₂, θ₁+θ₂)
#
# `to_cartesian()` - static method: (r, θ) → (a, b)
#
# `to_polar(real, imag)` - static method: (a, b) → (r, θ)
#
# `conjugate()` - returns new ComplexPolar with angle negated
#
# Constraints:
#
# * Store only (r, θ) after initialization
#
# * θ in degrees, range [-180, 180)
#
# * Handle multiplication with angle wrapping
#
#
# Example:
#
#     >>> z1 = ComplexPolar(1, 1)  # 1+i → (1.41, 45)
#     >>> z2 = ComplexPolar(0, 1)  # i → (1, 90)
#     >>> z3 = z1 * z2
#     >>> print(z1, z2, z3)
#     (1.41, 45.00) (1.00, 90.00) (1.41, 135.00°)

# %%
###your solution here

# %% [markdown]
# Run the script below to verify your solution

# %%
import math
from typing import Optional

# Test cases
def run_tests():
    """Run all test cases and return number of failures."""
    failed = 0
    total = 0
    
    # Test 1: Basic initialization - 1+i = √2∠45°
    total += 1
    try:
        z = ComplexPolar(1, 1)
        if abs(z.r - math.sqrt(2)) > 1e-6 or abs(z.theta - 45) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 2: Initialization - i = 1∠90°
    total += 1
    try:
        z = ComplexPolar(0, 1)
        if abs(z.r - 1.0) > 1e-6 or abs(z.theta - 90) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 3: Initialization - -1 = 1∠180° (or -180°)
    total += 1
    try:
        z = ComplexPolar(-1, 0)
        if abs(z.r - 1.0) > 1e-6 or (abs(z.theta - 180) > 1e-4 and abs(z.theta + 180) > 1e-4):
            failed += 1
    except:
        failed += 1
    
    # Test 4: Initialization - -i = 1∠-90°
    total += 1
    try:
        z = ComplexPolar(0, -1)
        if abs(z.r - 1.0) > 1e-6 or abs(z.theta + 90) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 5: Zero initialization
    total += 1
    try:
        z = ComplexPolar(0, 0)
        if abs(z.r) > 1e-6:
            failed += 1
    except:
        failed += 1
    
    # Test 6: None initialization
    total += 1
    try:
        z = ComplexPolar()
        if abs(z.r) > 1e-6:
            failed += 1
    except:
        failed += 1
    
    # Test 7: __repr__ formatting
    total += 1
    try:
        z = ComplexPolar(1, 1)
        s = repr(z)
        if "1.41" not in s and "45.00" not in s:
            failed += 1
    except:
        failed += 1
    
    # Test 8: __eq__ - same values
    total += 1
    try:
        z1 = ComplexPolar(1, 1)
        z2 = ComplexPolar(1, 1)
        if not (z1 == z2):
            failed += 1
    except:
        failed += 1
    
    # Test 9: __eq__ - different values
    total += 1
    try:
        z1 = ComplexPolar(1, 1)
        z2 = ComplexPolar(1, 0)
        if z1 == z2:
            failed += 1
    except:
        failed += 1
    
    # Test 10: __eq__ - zeros
    total += 1
    try:
        z1 = ComplexPolar(0, 0)
        z2 = ComplexPolar()
        if not (z1 == z2):
            failed += 1
    except:
        failed += 1
    
    # Test 11: Multiplication - (1+i) * i = -1+i
    total += 1
    try:
        z1 = ComplexPolar(1, 1)  # √2∠45°
        z2 = ComplexPolar(0, 1)  # 1∠90°
        z3 = z1 * z2             # √2∠135°
        if abs(z3.r - math.sqrt(2)) > 1e-6 or abs(z3.theta - 135) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 12: Multiplication - angle wrapping
    total += 1
    try:
        z1 = ComplexPolar(1, 0)
        z1.r = 2.0
        z1.theta = 100.0
        z2 = ComplexPolar(1, 0)
        z2.r = 3.0
        z2.theta = 100.0
        z3 = z1 * z2  # Should be 6∠200° which wraps to -160°
        if abs(z3.r - 6.0) > 1e-6 or abs(z3.theta + 160) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 13: Multiplication with zero
    total += 1
    try:
        z1 = ComplexPolar(1, 1)
        z2 = ComplexPolar(0, 0)
        z3 = z1 * z2
        if abs(z3.r) > 1e-6:
            failed += 1
    except:
        failed += 1
    
    # Test 14: to_cartesian static method
    total += 1
    try:
        a, b = ComplexPolar.to_cartesian(math.sqrt(2), 45)
        if abs(a - 1.0) > 1e-6 or abs(b - 1.0) > 1e-6:
            failed += 1
    except:
        failed += 1
    
    # Test 15: to_polar static method
    total += 1
    try:
        r, theta = ComplexPolar.to_polar(1, 1)
        if abs(r - math.sqrt(2)) > 1e-6 or abs(theta - 45) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 16: Conjugate of 1+i
    total += 1
    try:
        z = ComplexPolar(1, 1)  # √2∠45°
        zc = z.conjugate()      # √2∠-45°
        if abs(zc.r - math.sqrt(2)) > 1e-6 or abs(zc.theta + 45) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 17: Conjugate of i
    total += 1
    try:
        z = ComplexPolar(0, 1)  # 1∠90°
        zc = z.conjugate()      # 1∠-90°
        if abs(zc.r - 1.0) > 1e-6 or abs(zc.theta + 90) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 18: Double conjugate returns original
    total += 1
    try:
        z = ComplexPolar(3, 4)
        zcc = z.conjugate().conjugate()
        if not (z == zcc):
            failed += 1
    except:
        failed += 1
    
    # Test 19: Multiplication by conjugate gives real number
    total += 1
    try:
        z = ComplexPolar(1, 1)
        zc = z.conjugate()
        result = z * zc
        # Should be |z|²∠0° = 2∠0°
        if abs(result.r - 2.0) > 1e-6 or abs(result.theta) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 20: Chain multiplication
    total += 1
    try:
        z1 = ComplexPolar(1, 0)  # 1∠0°
        z2 = ComplexPolar(0, 1)  # 1∠90°
        z3 = ComplexPolar(-1, 0)  # 1∠180°
        result = z1 * z2 * z3  # Should be 1∠270° = 1∠-90°
        if abs(result.r - 1.0) > 1e-6 or abs(result.theta + 90) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 21: Large angle wrapping
    total += 1
    try:
        z1 = ComplexPolar(1, 0)
        z1.r = 1.0
        z1.theta = 170.0
        z2 = ComplexPolar(1, 0)
        z2.r = 1.0
        z2.theta = 30.0
        z3 = z1 * z2  # 200° → -160°
        if abs(z3.r - 1.0) > 1e-6 or abs(z3.theta + 160) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 22: Negative real number
    total += 1
    try:
        z = ComplexPolar(-5, 0)
        if abs(z.r - 5.0) > 1e-6:
            failed += 1
    except:
        failed += 1
    
    # Test 23: Round-trip conversion
    total += 1
    try:
        original_r, original_theta = 3.5, 67.3
        a, b = ComplexPolar.to_cartesian(original_r, original_theta)
        r, theta = ComplexPolar.to_polar(a, b)
        if abs(r - original_r) > 1e-6 or abs(theta - original_theta) > 1e-4:
            failed += 1
    except:
        failed += 1
    
    # Test 24: Multiplication commutativity
    total += 1
    try:
        z1 = ComplexPolar(2, 3)
        z2 = ComplexPolar(1, 4)
        p1 = z1 * z2
        p2 = z2 * z1
        if not (p1 == p2):
            failed += 1
    except:
        failed += 1
    
    # Test 25: Specific example from problem
    total += 1
    try:
        z1 = ComplexPolar(1, 1)  # 1+i → √2∠45°
        z2 = ComplexPolar(0, 1)  # i → 1∠90°
        z3 = z1 * z2             # Should be √2∠135°
        
        # Verify through Cartesian
        a, b = ComplexPolar.to_cartesian(z3.r, z3.theta)
        # (1+i)*i = i + i² = i - 1 = -1 + i
        if abs(a + 1) > 1e-5 or abs(b - 1) > 1e-5:
            failed += 1
    except:
        failed += 1
    
    return failed, total


# Run all tests
failed_count, total_count = run_tests()
print(f"Failed: {failed_count}/{total_count}")
