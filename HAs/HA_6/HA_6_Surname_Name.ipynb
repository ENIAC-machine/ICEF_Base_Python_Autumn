# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm #for fancy progress bars

from IPython.core.display import HTML #fancy table formatting
table_css = 'table {align:left;display:block} '
HTML('<style>{}</style>'.format(table_css))

# %% [markdown]
# # Problem 1 (30 pts). Employees Earning More Than Their Managers

# %% [markdown]
# Table: ```employee```
#
#
# | Column Name | Type    |
# |-------------|---------|
# | id          | int     |
# | name        | varchar |
# | salary      | int     |
# | managerId   | int     |
#
#
#
# id is the primary key (column with unique values) for this table.\
# Each row of this table indicates the ID of an employee, their name, salary, and the ID of their manager.
#
#
# Write a solution to find the employees who earn more than their managers along with their manager's name and the difference between their salaries (positive)\
# Note that you need to consider **only the employees, whose salary is larger than that of their manager by at least 10 percent**
#
# Return the result table in any order.
#
# The result format is in the following example.
#
#
#
# Example 1:
#
# Input: \
# Employee table:
#
# | id | name  | salary | managerId |
# |----|-------|--------|-----------|
# | 1  | Joe   | 70000  | 3         |
# | 2  | Henry | 80000  | 4         |
# | 3  | Sam   | 60000  | Null      |
# | 4  | Max   | 90000  | Null      |
#
#
# Output:
#
# | Employee | Manager | Difference |
# |----------|---------|------------|
# | Joe      | Sam     |   10000    |
#
#
# Explanation: Joe is the only employee who earns more than his manager.
#
# Constraints:
# 1. You must use the ```pd.DataFrame.apply``` method

# %%
def find_employees(employee: pd.DataFrame) -> pd.DataFrame:
    '''
    Find the employees, whose salary is larger than that of their managers by more than 10 percent

    Inputs:
        employee: pd.DataFrame - DataFrame with managers and employees

    Outputs:
        df_out: pd.DataFrame - DataFrame with the data on the employees, who earn more than their manager by over 10 percent

    '''
    #Conditions to be asserted

    ###your code here
    
    return df_out

# %%
#code for you to verify yourselves

df_1 = pd.DataFrame({'id' : [1,2,3,4], 'name' : ['Joe', 'Henry', 'Sam', 'Max'],\
                     'salary' : [70_000, 80_000, 60_000, 90_000], 'managerId' : [3, 4, np.nan, np.nan]})

df_1['managerId'] = df_1['managerId'].astype('Int32')

anw_1 = pd.DataFrame({'Employee' : ['Joe'], 'Manager' : ['Sam'], 'Difference' : [10_000]})

df_2 = pd.DataFrame(columns=['id', 'name', 'salary', 'managerId'])
anw_2 = pd.DataFrame(columns=['Employee', 'Manager', 'Difference'])

df_3 = pd.DataFrame({'id' : [1,2], 'name' : ['Mark', 'Jack'],\
                     'salary' : [30_000, 28_000], 'managerId' : [2, np.nan]})
anw_3 = pd.DataFrame(columns=['Employee', 'Manager', 'Difference'])

dfs = [df_1, df_2, df_3]
anws = [anw_1, anw_2, anw_3]

for idx, (ans, df) in enumerate(zip(anws, dfs)):
    if find_employees(df).equals(ans):
        print(f'\rSuccess for iteration {idx}', end='')

    else:
        print('You got a mistake!')

# %% [markdown]
# # Problem 2 (30 pts). Second Highest Salary

# %% [markdown]
# Table: ```df```
#
# | Column Name | Type |
# |-------------|------|
# | id          | int  |
# | salary      | int  |
#
# id is the primary key (column with unique values) for this table.\
# Each row of this table contains information about the salary of an employee.
#
#
# Write a solution to find the second highest distinct salary from the Employee table. If there is no second highest salary, return null (return ```pd.NA``` in Pandas).
#
# The result format is in the following example.
#
#
# Example 1:
#
# Input:
# Employee table:
#
# | id | salary |
# |-------------|------|
# | 1  | 100    |
# | 2  | 200    |
# | 3  | 300    |
#
# Output:
#
# | SecondHighestSalary |
# |---------------------|
# | 200                 |

# %%
def SHS(employee: pd.DataFrame) -> pd.DataFrame:
    '''
    Finds the second highest paying salary in the DataFrame

    Inputs:
        df: pd.DataFrame - DataFrame with 2 columns, 'id' and 'salary'

    Outputs:
        df_out : pd.DataFrame - DataFrame with a single entry- second highest salary

    '''
    assert isinstance(df, pd.DataFrame), f'Wrong type of input argument, expected pd.DataFrame, got {type(df)}'

    ### your code for the solution
    
    return df_out

# %%
#For checking the correctness of your solution

np.random.seed(420)

for _ in tqdm(range(10_000), desc='Checking solutions'):
    N = np.random.randint(1, 1_000, 1)[0]
    df = pd.DataFrame({'id' : np.arange(1, N+1), 'salary' : np.round(np.clip(np.random.normal(500, 5, N), 0, 1e6), 2)})
    df[df['salary'] == df['salary'].min()] = [df[df['salary'] == df['salary'].min()]['id'].values[0], df['salary'].max()-1e-6]
    val = pd.NA if pd.unique(df['salary']).shape[0] == 1 else df['salary'].max() - 1e-6
    assert pd.isna(SHS(df).iloc[0, 0]) if val is pd.NA else SHS(df).iloc[0, 0] == val

# %% [markdown]
# # Problem 3 (10 pts). Nth Highest Salary

# %% [markdown]
# Table: ```df```
#
#
# | Column Name | Type |
# |-------------|------|
# | id          | int  |
# | salary      | int  |
#
# id is the primary key (column with unique values) for this table.\
# Each row of this table contains information about the salary of an employee.
#
#
# Write a solution to find the nth highest distinct salary from the Employee table. If there are less than n distinct salaries, return null.
#
# The result format is in the following example.
#
# Input:
# Employee table:
#
# | id | salary |
# |-------------|------|
# | 1  | 100    |
# | 2  | 200    |
# | 3  | 300    |
#
# n = 2
# Output:
#
# | getNthHighestSalary(2) |
# |-------------|
# | 200                    |

# %%
def NHS(df: pd.DataFrame, n: int) -> pd.DataFrame:
    '''
    Inputs:
        df: pd.DataFrame - data on salaries
        n: int - order of maxima of salary to find

    Outputs:
        df_out : pd.DataFrame - output DataFrame

    '''
    assert  ###your code to assert conditions that need to be asserted

    ###your code for solution

    return df_out

# %%
#For checking the correctness of your solution

np.random.seed(420)

for _ in tqdm(range(10_000), desc='Checking solutions'):
    N = np.random.randint(1, 1_000, 1)[0]
    n = np.random.randint(1, 1_000, 1)[0]
    df = pd.DataFrame({'id' : np.arange(1, N+1), 'salary' : np.round(np.linspace(10_000, 0, N), 2)})
    val = pd.NA if pd.unique(df['salary']).shape[0] < n else df.iloc[n-1, 1].copy()
    df = pd.concat([df, df], axis=0).sample(2*N)
    df['id'] = np.arange(2*N)+1
    df.reset_index(drop=True, inplace=True)
    assert pd.isna(NHS(df, n).iloc[0, 0]) if val is pd.NA else SHS(df, n).iloc[0, 0] == val

# %% [markdown]
# # Problem 4 (30 pts). Highest salary in the Department

# %% [markdown]
# Table: ```Employee```
#
#
# | Column Name  | Type    |
# |--------------|---------|
# | id           | int     |
# | name         | varchar |
# | salary       | int     |
# | departmentId | int     |
#
# id is the primary key (column with unique values) for this table.\
# departmentId is a foreign key (reference columns) of the ID from the Department table.\
# Each row of this table indicates the ID, name, and salary of an employee. It also contains the ID of their department.
#
#
# Table: ```Department```
#
#
# | Column Name | Type    |
# |-------------|---------|
# | id          | int     |
# | name        | varchar |
#
# id is the primary key (column with unique values) for this table. It is guaranteed that department name is not NULL.\
# Each row of this table indicates the ID of a department and its name.
#
#
# Write a solution to find employees who have the highest salary in each of the departments.
#
# Return the result table in any order.
#
# The result format is in the following example.
#
# Input:
# Employee table:
#
# | id | name  | salary | departmentId |
# |-------------|---------|-|-|
# | 1  | Joe   | 70000  | 1            |
# | 2  | Jim   | 90000  | 1            |
# | 3  | Henry | 80000  | 2            |
# | 4  | Sam   | 60000  | 2            |
# | 5  | Max   | 90000  | 1            |
#
# Department table:
#
# | id | name  |
# |-------------|---------|
# | 1  | IT    |
# | 2  | Sales |
#
# Output:
#
# | Department | Employee | Salary |
# |-------------|---------|-|
# | IT         | Jim      | 90000  |
# | Sales      | Henry    | 80000  |
# | IT         | Max      | 90000  |

# %%
def HSD(employee: pd.DataFrame, department: pd.DataFrame) -> pd.DataFrame:
    '''
    Finds the largest salaries in departments

    Inputs:
        employee: pd.DataFrame - data on employees
        Department: pd.DataFrame - data on Departments

    Outputs:
        df_out: pd.DataFrame - data on the largest salaries in the departments

    '''
    assert isinstance(employee, pd.DataFrame) and isinstance(Department, pd.DataFrame),
        f"Wrong types of inputs, expected pd.DataFrame for both, got {type(employee)} for employee and {type(department)} for department"

    ###your solution here

    return df_out

# %%
#Script to verify your code
#If the code below doesn't work, try deleting the '--user' flag
#uncomment the command below to install the names library 
# !pip install names -q --user

from names import get_first_name

np.random.seed(169)

for _ in tqdm(range(100), desc='Checking solutions'):
    N_d = np.random.randint(1, 15, 1)[0]
    N_ppl_per_d = np.random.randint(1_000, 10_000, N_d)
    N_ttl = N_ppl_per_d.sum()
    salaries = np.round(np.random.normal(1_000, 5, N_ttl), 2)
    N_ppl_cum = N_ppl_per_d.cumsum()
    salaries_max = [salaries[0 if i == 0 else N_ppl_cum[i-1] : N_ppl_cum[i]].max() for i in range(N_d)]
    nms = [get_first_name() for __ in range(N_ttl)]
    employee = pd.DataFrame({'id' : np.arange(1, N_ttl+1), 'name' : nms, 'salary' : salaries,
                             'departmentId' : np.concatenate([[idx+1]*n_ppl_per_d for idx, n_ppl_per_d in enumerate(N_ppl_per_d)])
                            })
    department = pd.DataFrame({'id' : np.arange(1, N_d+1), 'name' : [f'Dep_{i}' for i in range(1, N_d+1)]})
    res = HSD(employee, department)
    assert set(res['salary']) == set(salaries_max) and res['salary'].shape[0] == employee[employee['salary'].isin(salaries_max)].shape[0], 'Wrong solution!'
