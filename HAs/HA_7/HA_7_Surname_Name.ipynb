# %% [markdown]
# # Imports

# %%
###your imports here

# %% [markdown]
# # Problem 1 (50 pts). Visualizing a pivot table

# %% [markdown]
# Given a file ```data.csv``` you should create a graph with the Closing and Opening prices of the stock for each date. Remember to include a legend with the line description, the title of the graph (sensible). Make the Opening\
# price blue and the Closing price black

# %%
###your code here

# %% [markdown]
# # Problem 2 (50 pts). Non-trivial plot

# %% [markdown]
# Create a plot mosaic consisting of 4 subplots:\
# On the first one you should display the quadratic polynomial $\large f(x) = x^2 - 10x + 5$ at points $\large x \in [-100, 100]$\
# On the second one you should display an exponential function $\large g(x) = exp(1/x) $ at points $\large x \in [-10, 10]; y \in [0, 2]$\
# On the third one you should display the qubic polynomial $\large l(x) = 5x^3 - 7x^2 + 10x - 7$ at points $\large x \in [-50, 50]$\
# On the fourth one you should display a cosine function $\large h(x) = cos(x) $ at points $\large x \in [-2\pi, 2\pi]; y \in [-1, 1]$\
# Overall, you should replicate the graph below

# %%
###your code here
