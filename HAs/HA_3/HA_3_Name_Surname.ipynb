# %% [markdown]
# # Problem 1 (30 pts). Investment calculator
# Write the functions for the user-interactive calculator with memory

# %%
def file_IO(filename: str | None = None, lines: list | None = None, out: str = "list") -> list:
    '''
    Opens the file, reads out all of its contents and writes the desired lines into it

    Inputs:
        filename: str - name of the file to interact with (with path and extension included)
        lines: list - list of lines to write inside the file
        out: str - output format, can be "list" or "string", default is "list"

    Outputs:
        contents: list - list of lines of the desired file
    '''

    try:

        ### Fill out how to open the file, read its contents and write what the user asks inside of it. Note that there are different possible outputs
        ### of the file's contents

    except:

        ### You need to print out an error message in case there's an error while opening the file and return an empty value

    finally:

        ### Close the file if your code requires it, if not, you can delete this block

# %%
def calculate_profit(init_deposit:float = 0, rate:float = 0, num_periods:int = 0, period_deposit:float = 0)-> tuple[float, float]:
    '''
    Calculates the profit from investment given initial parameters

    Inputs:
        init_deposit: float - initial money invested
        rate: float - interest rate per period
        num_periods: int - number of periods of the investment
        period_deposit: float - deposit per period 

    Outputs:
        FV: float - value after the investment matures
        fr: float - forward rate, rate for all of the periods

    '''
    #some conditions should be asserted... 
    assert
    
    ### your code

    fr = FV / init_deposit 
    return FV, fr

# %%
def calculator() -> None:
    '''
    Implements the calculator, interacts until the user enters 'STOP'

    Inputs:
        -

    Outputs:
        -
    '''

    welcome ="\n\nHello!\n\tPlease enter the desired initial deposit, interest rate, number of periods of investment and the per period deposit:\n"
    print(welcome)
    
    while True: #create an infinite loop

        try:
            initial_deposit = input("Initial deposit: ")
            if initial_deposit == "STOP":
                ### your code here
            else:
                initial_deposit = ### your code here    
            interest_rate = float(input("Interest rate: "))
            number_of_periods = int(input("Number of periods: "))
            per_period_deposit = float(input("Per period deposit: "))

        except:
            print("Wrong input! Write again!")

        finally:
            ### your code here 

            ### Fill the missed entries in the string and the function call below
            print(f'Future value of your investment is {}, your forward interest rate is {}')
            hist = file_IO() #writing the variables and the result in the file

# %% [markdown]
# # Problem 2 (30 pts). Algorithmic headaches
# Implement a couple of interesting abstract tasks. For the sqrt function, [this link](https://en.wikipedia.org/wiki/Newton%27s_method) will be useful

# %%
def sqrt(x: float) -> float:
    '''
    Given a non-negative float number x find its square root by using nothing but summation, division, subtraction and multiplication

    Inputs:
        x: float - number to find the root of

    Outputs:
        root: float - square root of x
    '''

    ### your code here
    return root

# %%
def ugly_num_check(x: int) -> bool:
    '''
    An ugly number is a positive integer which does not have a prime factor other than 2, 3, and 5.
    Given an integer n, return true if n is an ugly number

    Inputs:
        x: int - some non-negative integer 

    Outputs:
        isUgly: bool - flag whether x is ugly
    '''

    ### your code here

    return isUgly

# %%
def max_consec_nums(arr: list[int], x: int) -> int:
    '''
    Given some array of integer values you need to find the maximum number of times number x occurs in the array CONSECUTIVELY

    Inputs:
        arr: list - array of integers
        x: int - target integer

    Outputs:
        max_consec: int - maximum amount of times number x appears in arr consecutively
    '''

    ### your code here

    return max_consec
